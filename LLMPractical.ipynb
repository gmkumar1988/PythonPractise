# %%
# %pip install -qq google-genai pandas scikit-learn matplotlib seaborn python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
# ensure typing_extensions is recent enough to provide Sentinel
# %pip install -q --upgrade typing_extensions
import os
# ensure typing_extensions is recent enough to provide Sentinel
# %pip install -q --upgrade typing_extensions cryptography
try:
    import google.genai as genai
except Exception as e:
    print("google.genai import failed:", e)
    print("Trying to reinstall cryptography and retry...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", "--force-reinstall", "cryptography"])
    importlib.invalidate_caches()
    try:
        import google.genai as genai
    except Exception as e2:
        raise RuntimeError(
            "Import still failed. On macOS you may need to install OpenSSL via Homebrew and rebuild cryptography:\n"
            "  brew install openssl\n"
            "  export LDFLAGS='-L/usr/local/opt/openssl/lib' CFLAGS='-I/usr/local/opt/openssl/include'\n"
            "  pip install --force-reinstall --no-binary cryptography cryptography\n"
            "Or try using a virtual environment/conda with a matching OpenSSL.\n"
        ) from e2
from dotenv import load_dotenv
import pandas as pd

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
client = genai.Client(api_key=GEMINI_API_KEY)
from dotenv import load_dotenv
import pandas as pd

import warnings
import sys, subprocess, importlib
warnings.filterwarnings("ignore", category=FutureWarning)

load_dotenv()
GEMINI_API_KEY = os.getenv("AQ.Ab8RN6Ig9QcegOEKXCGWrWL5hQKA_5M_pGiEX1eyTrW0lx4p_Q")
client = genai.Client(api_key=GEMINI_API_KEY)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# google.genai import failed: dlopen(/Users/maheshg/Dropbox/git repos/PythonPractise/PythonPractise-1/study/lib/python3.9/site-packages/cryptography/hazmat/bindings/_rust.abi3.so, 0x0002): symbol not found in flat namespace '_ERR_get_error_all'
# Trying to reinstall cryptography and retry...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 8
#       7 try:
# ----> 8     import google.genai as genai
#       9 except Exception as e:
#
# File ~/Dropbox/git repos/PythonPractise/PythonPractise-1/study/lib/python3.9/site-packages/google/genai/__init__.py:20
#      19 from . import version
# ---> 20 from .client import Client
#      23 __version__ = version.__version__
#
# ...
