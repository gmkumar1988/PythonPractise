# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/maheshg/Dropbox/Sample Datasets Kaggle/Youtube_data/UScomments.csv' , on_bad_lines='skip',
                 encoding= 'utf-8')

# df.head()
df['comment_text'].values[0]
df.shape
# df = df.head()
print(df)

# #Perform Quick EDA from the Youtube Dataset :
# df['likes'].value_counts()
# Out:
#            video_id                                       comment_text likes  \
# 0       XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1       XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2       XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3       XpVt6Z1Gjjo                                MY FAN . attendance     3
# 4       XpVt6Z1Gjjo                                         trending 😉     3
# ...             ...                                                ...   ...
# 691395  EoejGgUNmVU                                             Лучшая     1
# 691396  EoejGgUNmVU  qu'est ce que j'aimerais que tu viennes à Roan...     0
# 691397  EoejGgUNmVU                          Ven a mexico! 😍 te amo LP     0
# 691398  EoejGgUNmVU                                    Islığı yeter...     0
# 691399  EoejGgUNmVU  Kocham tą piosenkę😍❤❤❤byłam zakochana po uszy ...     0
#
#        replies
# 0            0
# ...

# %%
print(df.dtypes)
# Out:
# video_id        object
# comment_text    object
# likes           object
# replies         object
# dtype: object

# %%
df['likes'] = pd.to_numeric(df['likes'], errors='coerce')

# %%
df['video_id'] = pd.to_numeric(df['video_id'], errors='coerce')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         video_id                                       comment_text  likes  \
# 0            NaN                  Logan Paul it's yo big day ‼️‼️‼️    4.0
# 1            NaN  I've been following you from the start of your...    3.0
# 2            NaN                 Say hi to Kong and maverick for me    3.0
# 3            NaN                                MY FAN . attendance    3.0
# 4            NaN                                         trending 😉    3.0
# ...          ...                                                ...    ...
# 691395       NaN                                             Лучшая    1.0
# 691396       NaN  qu'est ce que j'aimerais que tu viennes à Roan...    0.0
# 691397       NaN                          Ven a mexico! 😍 te amo LP    0.0
# 691398       NaN                                    Islığı yeter...    0.0
# 691399       NaN  Kocham tą piosenkę😍❤❤❤byłam zakochana po uszy ...    0.0
#
#        replies
# 0            0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         video_id                                       comment_text  likes  \
# 0            NaN                  Logan Paul it's yo big day ‼️‼️‼️    4.0
# 1            NaN  I've been following you from the start of your...    3.0
# 2            NaN                 Say hi to Kong and maverick for me    3.0
# 3            NaN                                MY FAN . attendance    3.0
# 4            NaN                                         trending 😉    3.0
# ...          ...                                                ...    ...
# 691395       NaN                                             Лучшая    1.0
# 691396       NaN  qu'est ce que j'aimerais que tu viennes à Roan...    0.0
# 691397       NaN                          Ven a mexico! 😍 te amo LP    0.0
# 691398       NaN                                    Islığı yeter...    0.0
# 691399       NaN  Kocham tą piosenkę😍❤❤❤byłam zakochana po uszy ...    0.0
#
#        replies
# 0            0
# ...

# %%
ax = df['likes'].value_counts().sort_index().plot(kind='bar',title='Count of number of likes based on youtube video comments',
                                             figsize=(10,5)
                                            )
ax.set_label('Review Comments')
plt.show()

# %%
#Basic NLTK 
example = df['comment_text'][10]
print(example)
# Out:
# There should be a mini Logan Paul too!

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/maheshg/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.data.path.append('/Users/maheshg/Dropbox/git repos/PythonPractise/PythonPractise-1/study/lib/python3.9/site-packages/nltk')

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
text = 'Hello World'
tokens = word_tokenize(text)
# Out:
# [nltk_data] Downloading package punkt to /Users/maheshg/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[73], line 3
#       1 nltk.download('punkt')
#       2 text = 'Hello World'
# ----> 3 tokens = word_tokenize(text)
#
# File ~/Dropbox/git repos/PythonPractise/PythonPractise-1/study/lib/python3.9/site-packages/nltk/tokenize/__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
# ...
