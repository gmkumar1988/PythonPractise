# %%
from celery import Celery
app = Celery('hello',broker='amqb://guest@localhost//')

app.task
def hello():
    return 'hello world'

# %%
app.task
# Out:
# <bound method Celery.task of <Celery hello at 0x7f82b0639640>>
