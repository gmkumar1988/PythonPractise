# %%
fruit = 'apple'
index = 0 
while index < len(fruit):
    letter = fruit[index]
    print(letter)
    index = index + 1
# Out:
# a
# p
# p
# l
# e

# %%
fruit = 'apple'
for letter in fruit:
    print(letter)
# Out:
# a
# p
# p
# l
# e

# %%
fruit = 'apple'
for letter in fruit:
    print(letter)
# Out:
# a
# p
# p
# l
# e

# %%
index = 0 
while index < len(fruit):
    letter = fruit[index]
    print(letter)
    index = index + 1
# Out:
# a
# p
# p
# l
# e

# %%
word = 'banana'
count = 0
for letter in word:
    if letter == 'a':
        count = count + 1
print(count)
# Out:
# 3

# %%
s = 'Monty Python'
print(s[0:4])
print(s[6:7])
print(s[6:20])
print(s[:2])
print(s[8:])
print(s[:])
# Out:
# Mont
# P
# Python
# Mo
# thon
# Monty Python
