# %%
fruit = 'apple'
index = 0 
while index < len(fruit):
    letter = fruit[index]
    print(letter)
    index = index + 1
# Out:
# a
# p
# p
# l
# e

# %%
fruit = 'apple'
for letter in fruit:
    print(letter)
# Out:
# a
# p
# p
# l
# e
